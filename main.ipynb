# %% [markdown]
# Scotland-Housing-Stock-by-Tenure Stock by Tenure and Stock by tenure by LA

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path
    from io import BytesIO

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www2.gov.scot/Resource/0054/00540622.xls'
    inputFile = sourceFolder / '00540622.xls'

# %%
tab = loadxlstabs(inputFile, sheetids = 'Tbl Stock by Tenure')[0]
cell = tab.filter('Estimated stock of dwellings by tenure: 1993 to 2017')
year = cell.fill(DOWN).is_not_blank().is_not_whitespace()
tenure =  cell.shift(0,2).fill(RIGHT).is_not_blank().is_not_whitespace() | \
            cell.shift(0,3).fill(RIGHT).is_not_blank().is_not_whitespace()
observations = tenure.fill(DOWN).is_not_blank().is_not_whitespace().is_number()
# Out:
# Loading in\00540622.xls which has size 86528 bytes
# Table names: ['Tbl Stock by Tenure']

# %%
Dimensions = [
            HDim(year,'Year',DIRECTLY,LEFT),
            HDim(tenure,'Tenure',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit', 'dwellings-thousands')
            ]
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
table = c1.topandas()

# %%
tidy = pd.DataFrame()

# %%
table['Tenure'] = table['Tenure'].map(
    lambda x: {
        'Total number of dwellings (000s)' : 'total', 
        'Owner occupied' : 'privately-owned-dwellings/owner-occupied',
       'Rented privately or with a job/business (note this includes households living rent-free) 3' : 'privately-owned-dwellings/rented-privately-or-with-a-job-business',
       'From housing associations 4' : 'socially-rented-dwellings/from-housing-associations',
       'From local authorities, New Towns, Scottish Homes' : 'socially-rented-dwellings/from-local-authorities-new-towns-scottish-homes',
       'Total number of occupied dwellings (000s)' : 'occupied',
       'Total number of vacant dwellings (000s)' : 'all-vacants',
       'Total number occupied dwellings' : 'privately-owned-dwellings/occupied',
       'Vacant private dwellings and second homes': 'privately-owned-dwellings/vacant-private-dwellings-and-second-homes'
        }.get(x, x))

# %%
table['Year'] = table['Year'].str.strip()

# %%
table['Period'] = table['Year'].astype(str).str[-4:] + ' ' +  table['Year'].astype(str).str[:3]

# %%
import re
YEAR_RE = re.compile(r'[0-9]{4}')
YEAR_MONTH_RE = re.compile(r'([0-9]{4})\s+(JAN|FEB|Mar|APR|MAY|JUN|JUL|AUG|SEP|OCT|NOV|Dec)')
YEAR_QUARTER_RE = re.compile(r'([0-9]{4})\s+(Q[1-4])')

class Re(object):
  def __init__(self):
    self.last_match = None
  def fullmatch(self,pattern,text):
    self.last_match = re.fullmatch(pattern,text)
    return self.last_match

def time2period(t):
    gre = Re()
    if gre.fullmatch(YEAR_RE, t):
        return f"year/{t}"
    elif gre.fullmatch(YEAR_MONTH_RE, t):
        year, month = gre.last_match.groups()
        month_num = {'JAN': '01', 'FEB': '02', 'Mar': '03', 'APR': '04', 'MAY': '05', 'JUN': '06',
                     'JUL': '07', 'AUG': '08', 'SEP': '09', 'OCT': '10', 'NOV': '11', 'Dec': '12'}.get(month)
        return f"month/{year}-{month_num}"
    elif gre.fullmatch(YEAR_QUARTER_RE, t):
        year, quarter = gre.last_match.groups()
        return f"quarter/{year}-{quarter}"
    else:
        print(f"no match for {t}")

table['Period'] = table['Period'].apply(time2period)

# %%
import numpy as np
table['OBS'].replace('', np.nan, inplace=True)
table.dropna(subset=['OBS'], inplace=True)
table.rename(columns={'OBS': 'Value'}, inplace=True)
table['Value'] = table['Value'].astype(int)

# %%
table['Geography'] = 'S92000003'

# %%
table = table[['Period','Geography','Tenure','Measure Type','Value','Unit']]

# %%
tidy = pd.concat([tidy , table])

# %%
tab1 = loadxlstabs(inputFile, sheetids = 'Tbl Stock by tenure by LA')[0]
cell1 = tab1.filter('Estimated stock of dwellings by tenure and local authority: 2017')
geo = cell1.fill(DOWN).is_not_blank().is_not_whitespace()
tenure1 =  cell1.shift(0,1).fill(RIGHT).is_not_blank().is_not_whitespace() | \
            cell1.shift(0,2).fill(RIGHT).is_not_blank().is_not_whitespace()
observations1 = tenure1.fill(DOWN).is_not_blank().is_not_whitespace().is_number()
# Out:
# Loading in\00540622.xls which has size 86528 bytes
# Table names: ['Tbl Stock by tenure by LA']

# %%
Dimensions1 = [
            HDim(geo,'Geography',DIRECTLY,LEFT),
            HDim(tenure1,'Tenure',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit', 'dwellings-thousands')
            ]
c2 = ConversionSegment(observations1, Dimensions1, processTIMEUNIT=True)

# %%
table1 = c2.topandas()

# %%
table1['Tenure'] = table1['Tenure'].map(
    lambda x: {
        'Total number of dwellings (000s)' : 'total', 
        'Owner occupied' : 'privately-owned-dwellings/owner-occupied',
       'Rented privately or with a job/business (note this includes households living rent-free) 3' : 'privately-owned-dwellings/rented-privately-or-with-a-job-business',
       'From housing associations 4' : 'socially-rented-dwellings/from-housing-associations',
       'From local authorities, New Towns, Scottish Homes' : 'socially-rented-dwellings/from-local-authorities-new-towns-scottish-homes',
       'Total number of occupied dwellings (000s)' : 'occupied',
       'Total number of vacant dwellings (000s)' : 'all-vacants',
       'Total number occupied dwellings' : 'privately-owned-dwellings/occupied',
       'Vacant private dwellings and second homes': 'privately-owned-dwellings/vacant-private-dwellings-and-second-homes'
        }.get(x, x))

# %%
table1['Period'] = 'month/2017-03'

# %%
import numpy as np
table1['OBS'].replace('', np.nan, inplace=True)
table1.dropna(subset=['OBS'], inplace=True)
table1.rename(columns={'OBS': 'Value'}, inplace=True)
table1['Value'] = table1['Value'].astype(int)

# %%
table1['Geography'] = table1['Geography'].map(
    lambda x: {
        'Aberdeen City':'S12000033',
        'Aberdeenshire':'S12000034',
        'Angus':'S12000041',
        'Argyll & Bute':'S12000035',
        'Edinburgh, City of':'S12000036',
        'Clackmannanshire':'S12000005',
        'Dumfries & Galloway':'S12000006',
        'Dundee City':'S12000042',
        'East Ayrshire':'S12000008',
        'East Dunbartonshire':'S12000045',
        'East Lothian':'S12000010',
        'East Renfrewshire':'S12000011',
        'Falkirk':'S12000014',
        'Fife':'S12000015',
        'Glasgow City':'S12000046',
        'Highland':'S12000017',
        'Inverclyde':'S12000018',
        'Midlothian':'S12000019',
        'Moray':'S12000020',
        'Na h-Eileanan Siar':'S12000013',
        'North Ayrshire':'S12000021',
        'North Lanarkshire':'S12000044',
        'Orkney Islands':'S12000023',
        'Perth & Kinross':'S12000024',
        'Renfrewshire':'S12000038',
        'Scottish Borders':'S12000026',
        'Shetland Islands':'S12000027',
        'South Ayrshire':'S12000028',
        'South Lanarkshire':'S12000029',
        'Stirling':'S12000030',
        'West Dunbartonshire':'S12000039',
        'West Lothian':'S12000040',
        'Scotland':'S92000003'        
        }.get(x, x))

# %%
table1 = table1[['Period','Geography','Tenure','Measure Type','Value','Unit']]

# %%
tidy = pd.concat([tidy , table1])

# %%
out = Path('out')
out.mkdir(exist_ok=True)
tidy.to_csv(out / 'observations.csv', index = False)

# %%
tidy
# Out:
#             Period  Geography  \
# 0    month/1993-12  S92000003
# 1    month/1993-12  S92000003
# 2    month/1993-12  S92000003
# 3    month/1993-12  S92000003
# 4    month/1993-12  S92000003
# 5    month/1994-12  S92000003
# 6    month/1994-12  S92000003
# 7    month/1994-12  S92000003
# 8    month/1994-12  S92000003
# 9    month/1994-12  S92000003
# 10   month/1995-12  S92000003
# 11   month/1995-12  S92000003
# 12   month/1995-12  S92000003
# 13   month/1995-12  S92000003
# 14   month/1995-12  S92000003
# 15   month/1996-12  S92000003
# 16   month/1996-12  S92000003
# 17   month/1996-12  S92000003
# 18   month/1996-12  S92000003
# 19   month/1996-12  S92000003
# 20   month/1997-12  S92000003
# 21   month/1997-12  S92000003
# 22   month/1997-12  S92000003
# 23   month/1997-12  S92000003
# 24   month/1997-12  S92000003
# 25   month/1998-12  S92000003
# 26   month/1998-12  S92000003
# 27   month/1998-12  S92000003
# 28   month/1998-12  S92000003
# 29   month/1998-12  S92000003
# ..             ...        ...
# 267  month/2017-03  S12000029
# 268  month/2017-03  S12000029
# 269  month/2017-03  S12000029
# 270  month/2017-03  S12000030
# 271  month/2017-03  S12000030
# 272  month/2017-03  S12000030
# 273  month/2017-03  S12000030
# 274  month/2017-03  S12000030
# 275  month/2017-03  S12000030
# 276  month/2017-03  S12000030
# 277  month/2017-03  S12000030
# 278  month/2017-03  S12000030
# 279  month/2017-03  S12000039
# 280  month/2017-03  S12000039
# 281  month/2017-03  S12000039
# 282  month/2017-03  S12000039
# 283  month/2017-03  S12000039
# 284  month/2017-03  S12000039
# 285  month/2017-03  S12000039
# 286  month/2017-03  S12000039
# 287  month/2017-03  S12000039
# 288  month/2017-03  S12000040
# 289  month/2017-03  S12000040
# 290  month/2017-03  S12000040
# 291  month/2017-03  S12000040
# 292  month/2017-03  S12000040
# 293  month/2017-03  S12000040
# 294  month/2017-03  S12000040
# 295  month/2017-03  S12000040
# 296  month/2017-03  S12000040
#
#                                                 Tenure Measure Type  Value  \
# 0                                                total        Count   2193
# 1             privately-owned-dwellings/owner-occupied        Count   1217
# 2    privately-owned-dwellings/rented-privately-or-...        Count    154
# 3    socially-rented-dwellings/from-housing-associa...        Count     67
# 4    socially-rented-dwellings/from-local-authoriti...        Count    755
# 5                                                total        Count   2210
# 6             privately-owned-dwellings/owner-occupied        Count   1258
# 7    privately-owned-dwellings/rented-privately-or-...        Count    155
# 8    socially-rented-dwellings/from-housing-associa...        Count     77
# 9    socially-rented-dwellings/from-local-authoriti...        Count    721
# 10                                               total        Count   2230
# 11            privately-owned-dwellings/owner-occupied        Count   1293
# 12   privately-owned-dwellings/rented-privately-or-...        Count    155
# 13   socially-rented-dwellings/from-housing-associa...        Count     91
# 14   socially-rented-dwellings/from-local-authoriti...        Count    692
# 15                                               total        Count   2248
# 16            privately-owned-dwellings/owner-occupied        Count   1327
# 17   privately-owned-dwellings/rented-privately-or-...        Count    154
# 18   socially-rented-dwellings/from-housing-associa...        Count     99
# 19   socially-rented-dwellings/from-local-authoriti...        Count    668
# 20                                               total        Count   2266
# 21            privately-owned-dwellings/owner-occupied        Count   1366
# 22   privately-owned-dwellings/rented-privately-or-...        Count    154
# 23   socially-rented-dwellings/from-housing-associa...        Count    115
# 24   socially-rented-dwellings/from-local-authoriti...        Count    630
# 25                                               total        Count   2283
# 26            privately-owned-dwellings/owner-occupied        Count   1400
# 27   privately-owned-dwellings/rented-privately-or-...        Count    154
# 28   socially-rented-dwellings/from-housing-associa...        Count    121
# 29   socially-rented-dwellings/from-local-authoriti...        Count    608
# ..                                                 ...          ...    ...
# 267  privately-owned-dwellings/vacant-private-dwell...        Count      2
# 268  socially-rented-dwellings/from-housing-associa...        Count      6
# 269  socially-rented-dwellings/from-local-authoriti...        Count     24
# 270                                              total        Count     41
# 271                                           occupied        Count     39
# 272                                        all-vacants        Count      1
# 273                 privately-owned-dwellings/occupied        Count     31
# 274           privately-owned-dwellings/owner-occupied        Count     23
# 275          Rented privately or with a job/business 3        Count      8
# 276  privately-owned-dwellings/vacant-private-dwell...        Count      1
# 277  socially-rented-dwellings/from-housing-associa...        Count      2
# 278  socially-rented-dwellings/from-local-authoriti...        Count      5
# 279                                              total        Count     45
# 280                                           occupied        Count     43
# 281                                        all-vacants        Count      1
# 282                 privately-owned-dwellings/occupied        Count     27
# 283           privately-owned-dwellings/owner-occupied        Count     22
# 284          Rented privately or with a job/business 3        Count      4
# 285  privately-owned-dwellings/vacant-private-dwell...        Count      0
# 286  socially-rented-dwellings/from-housing-associa...        Count      5
# 287  socially-rented-dwellings/from-local-authoriti...        Count     10
# 288                                              total        Count     78
# 289                                           occupied        Count     77
# 290                                        all-vacants        Count      1
# 291                 privately-owned-dwellings/occupied        Count     57
# 292           privately-owned-dwellings/owner-occupied        Count     45
# 293          Rented privately or with a job/business 3        Count     11
# 294  privately-owned-dwellings/vacant-private-dwell...        Count      1
# 295  socially-rented-dwellings/from-housing-associa...        Count      7
# 296  socially-rented-dwellings/from-local-authoriti...        Count     13
#
#                     Unit
# 0    dwellings-thousands
# 1    dwellings-thousands
# 2    dwellings-thousands
# 3    dwellings-thousands
# 4    dwellings-thousands
# 5    dwellings-thousands
# 6    dwellings-thousands
# 7    dwellings-thousands
# 8    dwellings-thousands
# 9    dwellings-thousands
# 10   dwellings-thousands
# 11   dwellings-thousands
# 12   dwellings-thousands
# 13   dwellings-thousands
# 14   dwellings-thousands
# 15   dwellings-thousands
# 16   dwellings-thousands
# 17   dwellings-thousands
# 18   dwellings-thousands
# 19   dwellings-thousands
# 20   dwellings-thousands
# 21   dwellings-thousands
# 22   dwellings-thousands
# 23   dwellings-thousands
# 24   dwellings-thousands
# 25   dwellings-thousands
# 26   dwellings-thousands
# 27   dwellings-thousands
# 28   dwellings-thousands
# 29   dwellings-thousands
# ..                   ...
# 267  dwellings-thousands
# 268  dwellings-thousands
# 269  dwellings-thousands
# 270  dwellings-thousands
# 271  dwellings-thousands
# 272  dwellings-thousands
# 273  dwellings-thousands
# 274  dwellings-thousands
# 275  dwellings-thousands
# 276  dwellings-thousands
# 277  dwellings-thousands
# 278  dwellings-thousands
# 279  dwellings-thousands
# 280  dwellings-thousands
# 281  dwellings-thousands
# 282  dwellings-thousands
# 283  dwellings-thousands
# 284  dwellings-thousands
# 285  dwellings-thousands
# 286  dwellings-thousands
# 287  dwellings-thousands
# 288  dwellings-thousands
# 289  dwellings-thousands
# 290  dwellings-thousands
# 291  dwellings-thousands
# 292  dwellings-thousands
# 293  dwellings-thousands
# 294  dwellings-thousands
# 295  dwellings-thousands
# 296  dwellings-thousands
#
# [490 rows x 6 columns]
